# %% [markdown]
# # PART II
# ## Parameter recovery, model validation, bootstrap
#
# **In this tutorial, we will see how to:**
#
# - Validate the modeling results against experimental data
# - Test model recovery
# - Use bootstrapping to estimate the uncertainty of fitted model parameters

# %%
# # define the github path and authorization token
RAW_GITHUB_PATH = 'https://raw.githubusercontent.com/bambschool/BAMB2024/main/1-modeling_101/'

# # define the list of files to be downloaded
files = ['tutorial_1_lib.py']

for file in files:
    # !wget -O {file} "{RAW_GITHUB_PATH}{file}"
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.stats import pearsonr
import scipy.optimize as optimize

from tutorial_1_lib import *

# %% [markdown]
# **We use model B to generate fake data and in the following we assume that this is our actual experimental data.**

# %%
# generate fake data
n = 2500 # number of trials
stim_values = [-3, -2, -1, -.5, 0,.5, 1, 2, 3] # all possible values of stimulus evidence (i.e. signed stim strength)
# parameters of model B
sigma = 1 # decision noise
Lambda = 0.2 # proportion of lapses
#first generate experimental conditions for each trial
c = np.random.choice(a=['control', 'manipulation'], size=n) # condition
s = np.random.choice(a=stim_values, size=n) #stimulus evidence
#simulate model
r = simulate_modelB(s, c, sigma_d=sigma, Lambda=Lambda)
exp_data = pd.DataFrame({'stimulus': s, 'condition':c, 'response':r})

# %% [markdown]
# ---
# # II.1 Model validation
#
#
# As a very simple example for model validation, we will fit model A and B to the experimental data and compare how well the best-fitting model fits the psychometric curve.
#
# **Fit model B to the experimental data and show the model result and the psychometric curve.**

# %%
# fit model B
p_opt = optimize.minimize(lambda pp: -LogLikelihood_modelB(exp_data, pp[0], pp[1]), x0=[0.75, 0.1], bounds=[(0.1, 10), (0.01, 1)]).x

# Retrieve the optimized parameters
(sigma_d_hat, Lambda_hat) = p_opt

# plot model predictions
plot_model(lambda s,c: p_modelB(s,c,sigma_d=sigma_d_hat, Lambda=Lambda_hat))

# plot psychometric curve on top
plot_data_psychometric(exp_data)

# %% [markdown]
# **Now fit model A to the experimental data and compare to the result obtained above.**

# %% [markdown]
# Fitting the experimental data with model A that does not include lapses but a different $\sigma_m$, we get a worse fit for all the data points and the slope of the fit does not seem right.
#
# Of course, this is trivial here because we now that the "experimental data" actually includes lapses. It is important to note that not including a lapse rate can lead to real-world problems when fitting psychometric functions. We will talk more about this further below.

# %% [markdown]
# In general, it is a good idea to show not only that the best-fitting model validates, but that the alternative models do NOT validate (often many models are validated on simple behavioral metrics, and we need of specific patterns of behavior to arbitrate between different models).

# %% [markdown]
# ---
# # II.2. Parameter recovery

# %% [markdown]
# ## Simulation and fitting

# %% [markdown]
# **Simulate Model B to generate synthetic data, then fit these data.**
#
# We will do this step by step. We will first simulate model B using `simulate_modelB` with different random parameters $\sigma_d$ and $\lambda$. Note that the parameter recovery result will depend on the probability distribution used to sample the parameters.
#
# After simulating the model, we will fit the parameters using a maximum likelihood approach to get estimated values $\hat{\sigma_d}$ and $\hat{\lambda}$.

# %%
# loop over at least 100 repetitions
n_rep = 500

# specify parameters of the experiment
n = 2500  # number of trials
stim_values = [-3, -2, -1, -.5, 0,.5, 1, 2, 3]  # all possible values of stimulus evidence (i.e. signed stim strength)

# specify plaubsible range of model parameters
sigma = 0.5 + 2*np.random.rand(n_rep)
Lambda = 0.3 * np.random.rand(n_rep)


pars = np.zeros((n_rep,2))
for i in range(n_rep):
        
    # first generate experimental conditions for each trial
    c = np.random.choice(a=['control', 'manipulation'], size=n) # condition
    s = np.random.choice(a=stim_values, size=n) #stimulus evidence

    # simulate model B
    r = simulate_modelB(s, c, sigma_d=sigma[i], Lambda=Lambda[i])
    df = pd.DataFrame({'stimulus': s, 'condition': c, 'response': r})

    # fit model B
    result = optimize.minimize(lambda pp: -LogLikelihood_modelB(df, pp[0], pp[1]), x0=[0.75, 0.1], bounds=[(0.1, 10), (0.01, 1)])


    # store fitted parameters
    pars[i,0] = result.x[0]
    pars[i,1] = result.x[1]

# %%
print(pars)
# Out:
# [[0.88217559 0.14521474]
#  [0.86261953 0.16743936]
#  [1.63872855 0.19488966]
#  [1.2242723  0.23514334]
#  [2.23824282 0.07303792]
#  [0.75709171 0.15450815]
#  [1.164908   0.03047674]
#  [1.51067978 0.17775551]
#  [2.02993528 0.12363037]
#  [1.66856052 0.26990718]
#  [1.03257689 0.06083739]
#  [1.67259925 0.15447808]
#  [1.45349787 0.24347901]
#  [1.59323859 0.01      ]
#  [1.50180688 0.22480517]
#  [0.93531208 0.08358745]
#  [2.18430955 0.12432329]
#  [2.15234675 0.27251557]
#  [0.76131216 0.18839648]
#  [2.62183789 0.03523719]
#  [1.29281174 0.2276184 ]
#  [1.23845205 0.14558102]
#  [1.92696118 0.19559201]
#  [1.13335063 0.25039356]
#  [0.52598259 0.21109512]
#  [1.73435034 0.03930922]
#  [2.474866   0.15695361]
#  [1.21035799 0.13684041]
#  [1.4066618  0.10702834]
#  [2.08673075 0.01      ]
#  [0.58879453 0.17395283]
#  [0.9870845  0.23047021]
#  [0.61310331 0.02851395]
#  [2.24588435 0.26201443]
#  [2.13628015 0.03015132]
#  [1.59689413 0.07646483]
#  [0.81402155 0.21770271]
#  [1.17217073 0.10209754]
#  [2.11456236 0.27837363]
#  [0.9904418  0.23499311]
#  [1.87122276 0.03502551]
#  [2.25457664 0.2149459 ]
#  [1.34513257 0.28321981]
#  [1.78313347 0.06867028]
#  [1.23903833 0.1439144 ]
#  [1.55726885 0.01191236]
#  [0.84391887 0.05700449]
#  [0.59602052 0.28436352]
#  [1.44145239 0.03301138]
#  [1.53092108 0.06611084]
#  [1.98168904 0.0645781 ]
#  [0.71058169 0.08938518]
#  [2.09640277 0.13065636]
#  [2.36161894 0.01      ]
#  [0.90070684 0.33441684]
#  [1.01460828 0.21331786]
#  [0.80453142 0.28557979]
#  [1.67011814 0.01      ]
#  [1.87983452 0.23897364]
#  [1.30239462 0.12945268]
#  [0.99712223 0.14220228]
#  [2.45903912 0.07028867]
#  [2.14030871 0.01      ]
#  [0.93774401 0.16586762]
#  [1.41177973 0.06423375]
#  [0.71598891 0.24859489]
#  [1.63287472 0.3163342 ]
#  [0.89469934 0.26115016]
#  [2.34204667 0.2414176 ]
#  [2.6869646  0.08300677]
#  [1.74127246 0.03739573]
#  [0.67517839 0.17938217]
#  [2.32244114 0.12661179]
#  [0.71948073 0.25126495]
#  [1.82311521 0.11110469]
#  [1.40534939 0.08056336]
#  [1.22082275 0.04785292]
#  [1.64135295 0.19538873]
#  [1.24635738 0.18778235]
#  [1.98018384 0.05187792]
#  [1.10218977 0.10929783]
#  [2.40055975 0.01      ]
#  [2.4149195  0.01      ]
#  [0.51233799 0.2165843 ]
#  [1.51730002 0.02250118]
#  [1.82789284 0.27068303]
#  [1.67189331 0.23562078]
#  [1.86689249 0.20298946]
#  [2.44038715 0.01      ]
#  [1.85302441 0.1906356 ]
#  [1.19980736 0.10237829]
#  [2.30423266 0.1254963 ]
#  [1.9533496  0.25630711]
#  [1.63844751 0.12161738]
#  [1.34023316 0.14214511]
#  [2.55417242 0.06137304]
#  [1.66106095 0.26534409]
#  [1.48109307 0.14242847]
#  [1.48202327 0.3210397 ]
#  [0.72588235 0.29189659]
#  [2.30800566 0.22424571]
#  [0.65138524 0.28334877]
#  [2.33886178 0.26010842]
#  [2.20366403 0.01      ]
#  [1.01626652 0.13369689]
#  [1.38715207 0.04299564]
#  [1.22109039 0.10389623]
#  [0.60275655 0.02919871]
#  [1.61937423 0.37652471]
#  [1.41871989 0.01057723]
#  [1.55063504 0.23235962]
#  [1.10609693 0.17855273]
#  [0.94352371 0.21123362]
#  [0.72662985 0.17303545]
#  [0.48166371 0.28125034]
#  [2.52550591 0.30398633]
#  [1.75071579 0.1730584 ]
#  [0.94622608 0.24969565]
#  [1.80988927 0.01165814]
#  [1.70544945 0.22505391]
#  [1.19299763 0.2387827 ]
#  [2.07485733 0.22819631]
#  [2.14145752 0.04857507]
#  [1.42332928 0.18924891]
#  [2.11813668 0.05285388]
#  [1.97108508 0.01      ]
#  [1.92091916 0.03795903]
#  [1.27051949 0.05636949]
#  [0.94052098 0.20485287]
#  [2.13082977 0.28772477]
#  [1.23492293 0.33942829]
#  [0.84680608 0.26114999]
#  [2.12612054 0.22164683]
#  [2.5936186  0.01289464]
#  [1.68289943 0.20166054]
#  [1.44869326 0.04788355]
#  [2.45650378 0.05242076]
#  [0.55842183 0.14330489]
#  [1.67152586 0.1134892 ]
#  [1.94953058 0.2582597 ]
#  [1.35619632 0.26255688]
#  [1.39965978 0.01      ]
#  [1.30802109 0.14397621]
#  [1.19458655 0.2413869 ]
#  [0.91537233 0.01519903]
#  [1.55362335 0.22627871]
#  [2.09209677 0.08308487]
#  [1.20380543 0.20893195]
#  [0.83889275 0.22168935]
#  [1.97384106 0.19800229]
#  [1.23999263 0.04835425]
#  [2.26375937 0.08453904]
#  [1.7963907  0.05823319]
#  [1.36619438 0.1337496 ]
#  [0.78816867 0.19610211]
#  [0.86021603 0.28911147]
#  [2.03480961 0.17401603]
#  [1.09543347 0.19798053]
#  [0.98934092 0.05668345]
#  [2.66040683 0.15479289]
#  [0.73508891 0.01      ]
#  [1.35945236 0.04490824]
#  [0.89584806 0.18253246]
#  [0.70938485 0.07761877]
#  [1.25550455 0.1524577 ]
#  [1.97861916 0.10110373]
#  [0.86529663 0.06293061]
#  [1.55363908 0.02104119]
#  [0.75941548 0.05373624]
#  [1.64186362 0.01027238]
#  [2.29091911 0.15434453]
#  [1.9381225  0.25697116]
#  [1.22985596 0.23820076]
#  [1.9049421  0.28584666]
#  [1.19360011 0.21666207]
#  [2.5203407  0.1954416 ]
#  [1.27087299 0.01      ]
#  [1.66544218 0.33929476]
#  [1.87998146 0.21329771]
#  [1.70094275 0.04852908]
#  [1.032526   0.22563435]
#  [1.78118446 0.17482174]
#  [1.89631511 0.18745143]
#  [1.32787037 0.19109825]
#  [0.74264648 0.02291404]
#  [0.94785207 0.06525098]
#  [2.25186172 0.17421711]
#  [1.76067787 0.05551853]
#  [1.99998039 0.17680604]
#  [0.98955732 0.29320795]
#  [0.60598836 0.13253914]
#  [2.11538229 0.1591178 ]
#  [1.34735727 0.09152437]
#  [2.08115454 0.04942799]
#  [1.92823214 0.12975611]
#  [1.65577097 0.05282676]
#  [1.98096271 0.19942197]
#  [0.97748143 0.14943708]
#  [2.52771636 0.20843197]
#  [1.21947704 0.01      ]
#  [1.34793745 0.09740564]
#  [1.38789017 0.13665491]
#  [1.55465905 0.03355694]
#  [2.18571143 0.01627618]
#  [2.1785502  0.06307809]
#  [1.13314293 0.15257034]
#  [0.58664727 0.06347117]
#  [0.82622935 0.10016362]
#  [1.23882236 0.28209559]
#  [1.618577   0.16158107]
#  [2.1537821  0.30537298]
#  [2.27725229 0.11001899]
#  [0.72882185 0.12058738]
#  [0.5903193  0.31222323]
#  [2.88273917 0.01      ]
#  [1.39679937 0.29771413]
#  [0.7601117  0.0254143 ]
#  [0.84501412 0.12996326]
#  [1.14488119 0.15005225]
#  [2.31899411 0.05931846]
#  [1.7610746  0.2495396 ]
#  [0.85967728 0.27493373]
#  [0.50408825 0.06749732]
#  [1.63219586 0.33610275]
#  [2.13230347 0.09683201]
#  [2.15142694 0.32904524]
#  [1.15853064 0.03140474]
#  [1.20579092 0.10642947]
#  [2.35304755 0.20776057]
#  [1.35508991 0.08017482]
#  [0.80532536 0.17551625]
#  [1.96046345 0.09210069]
#  [2.09127127 0.26252815]
#  [1.62507976 0.08654117]
#  [0.992167   0.01      ]
#  [0.93776231 0.13038352]
#  [1.29270578 0.25402014]
#  [0.70103538 0.07913747]
#  [1.1242886  0.09202981]
#  [2.23368836 0.23966286]
#  [0.60347582 0.25408568]
#  [2.48343246 0.28468648]
#  [1.18706875 0.2071988 ]
#  [2.41177288 0.01      ]
#  [1.17280179 0.06636894]
#  [0.86657907 0.25676942]
#  [1.38925293 0.11141496]
#  [0.64501461 0.04538611]
#  [1.34920358 0.20168228]
#  [2.60151057 0.0901548 ]
#  [1.33152763 0.21626843]
#  [2.40724491 0.09153315]
#  [2.0395266  0.12412608]
#  [1.55367752 0.01076804]
#  [0.52590164 0.09807657]
#  [2.12016415 0.26744328]
#  [1.79453361 0.14757154]
#  [1.09893666 0.11568028]
#  [1.53472906 0.35363104]
#  [2.20550077 0.20886221]
#  [1.62270181 0.1364894 ]
#  [1.60910198 0.14294348]
#  [1.52353165 0.01      ]
#  [0.63942135 0.02091144]
#  [1.19931893 0.25247259]
#  [2.395612   0.19200796]
#  [1.51652079 0.30468384]
#  [1.48701015 0.08175829]
#  [1.60799148 0.1282014 ]
#  [2.34541824 0.19351153]
#  [0.96499009 0.09393646]
#  [2.34720591 0.01      ]
#  [0.68545055 0.26685323]
#  [2.01391825 0.0920083 ]
#  [0.5346217  0.16806241]
#  [1.52228303 0.19321892]
#  [2.07907569 0.10081559]
#  [2.20223455 0.08099293]
#  [1.92054648 0.03320494]
#  [1.16923808 0.08389701]
#  [0.98754242 0.04296386]
#  [0.97007094 0.25496861]
#  [0.77106649 0.0748918 ]
#  [0.62994329 0.02656078]
#  [1.62352965 0.01      ]
#  [0.56092022 0.15937069]
#  [2.20458444 0.10514197]
#  [1.56468831 0.27272437]
#  [1.59108357 0.11621826]
#  [1.432971   0.16872453]
#  [1.41570465 0.11724587]
#  [0.85449385 0.04852368]
#  [0.89597622 0.18853092]
#  [0.5578818  0.20087966]
#  [0.92151669 0.13489807]
#  [0.9059681  0.19173918]
#  [0.52599474 0.0306605 ]
#  [0.65753104 0.18543003]
#  [2.05844954 0.06735032]
#  [0.88009152 0.12041779]
#  [2.0057521  0.13740978]
#  [1.01205517 0.01      ]
#  [1.19112744 0.01      ]
#  [1.49405075 0.01538398]
#  [0.75369204 0.13734829]
#  [1.81438546 0.17951383]
#  [1.87968326 0.06290805]
#  [0.62602579 0.01563212]
#  [1.42042335 0.16900667]
#  [2.45291076 0.01      ]
#  [1.7262821  0.24803694]
#  [1.97715697 0.17742319]
#  [1.57919627 0.24725081]
#  [1.3274554  0.12373551]
#  [2.15982382 0.08603917]
#  [1.57302867 0.11629095]
#  [1.94984517 0.10562855]
#  [0.91568334 0.29705262]
#  [1.38924773 0.07795483]
#  [2.32650919 0.22741299]
#  [0.84374537 0.20179271]
#  [2.01848153 0.19602788]
#  [1.60409868 0.17238148]
#  [1.2440884  0.16991253]
#  [2.3775471  0.31986591]
#  [2.19919321 0.01      ]
#  [1.2376469  0.10450953]
#  [2.50937286 0.39735354]
#  [1.48005757 0.05869857]
#  [1.01036592 0.32585801]
#  [1.64348544 0.20906035]
#  [1.54859189 0.16214395]
#  [1.04477316 0.01      ]
#  [2.48162815 0.26252672]
#  [2.11758177 0.26504406]
#  [1.23568957 0.104283  ]
#  [1.82893105 0.17985276]
#  [1.82706313 0.09551225]
#  [0.8024713  0.05366175]
#  [2.38116662 0.20531377]
#  [2.05440986 0.08892616]
#  [2.5554134  0.09796309]
#  [1.13209245 0.17961869]
#  [1.38008532 0.0808333 ]
#  [0.9582789  0.27445778]
#  [1.24494183 0.16451433]
#  [1.39631537 0.02190519]
#  [0.560342   0.22761937]
#  [2.24534563 0.14712408]
#  [1.96129266 0.24377798]
#  [1.77414553 0.16527223]
#  [2.52169624 0.1364689 ]
#  [2.02332031 0.05067495]
#  [2.41410761 0.10448354]
#  [1.67216023 0.23786477]
#  [2.14493707 0.21946687]
#  [1.9245468  0.1820361 ]
#  [1.3292223  0.14387585]
#  [2.5595914  0.26857725]
#  [1.69942172 0.24401877]
#  [2.04407228 0.04515249]
#  [1.93936938 0.2967028 ]
#  [0.64758611 0.04547118]
#  [2.34647827 0.32483393]
#  [2.46960467 0.24299915]
#  [0.51699409 0.12254166]
#  [1.71595115 0.14468551]
#  [2.03625051 0.04835491]
#  [1.15079212 0.23452624]
#  [0.89128822 0.16758431]
#  [1.39876391 0.32466937]
#  [0.72267658 0.22214038]
#  [1.87376357 0.30102548]
#  [2.36390584 0.11974045]
#  [0.72975182 0.03959516]
#  [2.38501417 0.29256707]
#  [2.24749648 0.01472686]
#  [1.9738594  0.25367071]
#  [1.78972289 0.1518277 ]
#  [1.65238869 0.26811485]
#  [0.83557098 0.03895127]
#  [0.90723414 0.14591942]
#  [1.16774332 0.08484239]
#  [0.96593099 0.06512021]
#  [1.8992644  0.102025  ]
#  [1.35495081 0.26366249]
#  [1.99961129 0.27907714]
#  [1.93436872 0.10872696]
#  [1.52640465 0.31625445]
#  [0.90976571 0.25671781]
#  [1.51655859 0.07189614]
#  [1.08997234 0.07014288]
#  [0.69592786 0.24947882]
#  [1.41776244 0.24049585]
#  [1.81610661 0.23206969]
#  [2.26814725 0.13770508]
#  [0.80672878 0.07935406]
#  [0.6410954  0.24338502]
#  [1.29573757 0.29837782]
#  [0.86436847 0.07510146]
#  [1.12359641 0.01      ]
#  [0.87574104 0.21414059]
#  [1.51949515 0.15013826]
#  [0.59679885 0.12561835]
#  [1.66275455 0.17190254]
#  [1.48391012 0.04784606]
#  [1.55984572 0.01134529]
#  [1.11801559 0.11008358]
#  [1.99465617 0.01008464]
#  [0.74186034 0.27528228]
#  [1.47189403 0.18261946]
#  [1.6913482  0.18184781]
#  [2.20055994 0.13496392]
#  [0.80123344 0.29091704]
#  [1.69653993 0.01      ]
#  [1.90422999 0.10589878]
#  [2.01745325 0.1460569 ]
#  [1.93715176 0.04081622]
#  [1.42249465 0.27578384]
#  [2.13978625 0.01      ]
#  [0.72020503 0.07298606]
#  [2.05136699 0.09835383]
#  [1.75670541 0.27691549]
#  [1.7085497  0.10869856]
#  [1.4633866  0.02650307]
#  [0.74391323 0.03487665]
#  [1.18838147 0.23175955]
#  [2.54187219 0.2650142 ]
#  [1.38374576 0.03216442]
#  [2.13093511 0.11921089]
#  [1.68884482 0.22408192]
#  [0.62145188 0.07202036]
#  [1.31939026 0.09623849]
#  [1.40284572 0.09777293]
#  [1.28835351 0.06092219]
#  [0.84079894 0.33919621]
#  [1.41945532 0.13017915]
#  [0.90514945 0.24236326]
#  [2.44891363 0.01      ]
#  [0.74847972 0.0560025 ]
#  [2.04777375 0.2105742 ]
#  [1.20097652 0.22753014]
#  [1.5671031  0.01      ]
#  [0.93477125 0.07183572]
#  [1.80929115 0.0465993 ]
#  [1.50889659 0.02330349]
#  [1.7494995  0.02491914]
#  [0.77925355 0.26754992]
#  [0.71097721 0.07164778]
#  [1.10492545 0.17575408]
#  [1.90421541 0.16381627]
#  [0.55631031 0.09946273]
#  [1.07454899 0.16131182]
#  [2.25748655 0.18293149]
#  [0.76362442 0.01500174]
#  [0.94140115 0.26649508]
#  [2.46500022 0.26138169]
#  [1.99365754 0.28104464]
#  [0.84162049 0.10958418]
#  [0.88977615 0.16161835]
#  [0.86051514 0.16923922]
#  [1.21253698 0.04019257]
#  [2.30445502 0.40353209]
#  [1.99950277 0.04239658]
#  [1.40307888 0.09308007]
#  [1.68169924 0.26991061]
#  [1.68362643 0.21424075]
#  [1.94663756 0.03880217]
#  [1.99508992 0.01      ]
#  [2.37912911 0.21055363]
#  [1.19970016 0.14138777]
#  [1.27515602 0.14791576]
#  [0.85246063 0.26512286]
#  [0.79872599 0.28316495]
#  [1.28380687 0.29619676]
#  [1.02750502 0.26486272]
#  [0.77268799 0.16159989]
#  [0.72039471 0.01      ]
#  [1.09207556 0.12974278]
#  [0.73878569 0.30185917]
#  [0.91698071 0.19441428]
#  [1.18908948 0.04233109]
#  [1.88681441 0.19236076]
#  [1.51242838 0.12243454]
#  [2.29444621 0.18579779]
#  [1.68219296 0.29720554]
#  [1.20546318 0.19491062]
#  [1.4101426  0.15673773]
#  [0.71282663 0.0184187 ]
#  [0.72330293 0.01719425]
#  [0.62153423 0.03877248]
#  [1.41812317 0.22683705]
#  [0.54006254 0.1568425 ]
#  [2.69641348 0.08213135]
#  [1.82879292 0.02083192]
#  [1.65098075 0.01182787]
#  [1.35878343 0.01640164]
#  [2.45781154 0.23351331]
#  [0.92685451 0.03142473]
#  [1.40497459 0.3015939 ]]

# %% [markdown]
# ## Parameter recovery plots

# %% [markdown]
# We would like to visualise the fitted parameter values as a function of the generating parameter values. We will have one data point for each iteration. Here, you should use the generating values and the fitted values that you have stored in the section above. You should create two subplots, one for each parameter. Do you observe a fairly good agreement between the simulated and fit parameter values?

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 4))

#first subplot
axs[0].scatter(sigma, pars[:,0], marker='X', color='purple', alpha = 0.5)
axs[0].plot([0.2,2.7], [0.2,2.7], 'k--')
axs[0].set_title('noise standard deviation')
axs[0].set_xlabel('true sigma')
axs[0].set_ylabel('fitted sigma')

#second subplot
axs[1].scatter(Lambda, pars[:,1], marker='X', color='purple', alpha = 0.5)
axs[1].plot([0, 0.5], [0, 0.5], 'k--')
axs[1].set_title('lapse rate')
axs[1].set_xlabel('true lambda')
axs[1].set_ylabel('fitted lambda')

#third subplot
axs[2].scatter(pars[:,0], pars[:,1], marker='X', color='purple', alpha = 0.5)
axs[2].set_title('correlation between fitted parameters')
axs[2].set_xlabel('fitted sigma')
axs[2].set_ylabel('fitted lambda')

plt.tight_layout()  

plt.show()

# %% [markdown]
# These plots show strong correlation between true and fitted paramters and also reveal whether the correlation holds in some parameter regimes but not others. It also reveals any existing bias (e.g. a tendency to recover higher or lower values in average) which does not seem to be the case here.
#
# Depending on the parameter values that we obtain when fitting human behavior, the worse correspondence in some parameter range may or may not be problematic. It is be a good idea to use the range of parameters obtained from fitting the real data to test the quality of recovery within the range that matters.
#
# Reliable parameter recovery is particularly important for look at inter-individual differences in relation to questionnaire scores or brain data.

# %% [markdown]
#  **Optional:** Include a third subplot which shows a scatterplot of the fitted parameters $\sigma$ and $\lambda$. Also compute the correlation between the two parameters. How do you interpret the result?

# %%
(corrcoef, p_value) = pearsonr(pars[:,0], pars[:,1])
print('Correlation coefficient: ', corrcoef)
print('p_value: ', p_value)
# Out:
# Correlation coefficient:  -0.012101224403186214
# p_value:  0.7872185466159609

# %% [markdown]
# The fitted parameters are not correlated, indicating that our parameters are identifyable (they cannot be trade-off against each other)

# %% [markdown]
# ---
# # II.3 Parameter uncertainty estimation (bootstrap)

# %% [markdown]
# [Bootstrapping](https://en.wikipedia.org/wiki/Bootstrapping_(statistics)) is a widely applicable method to assess confidence/uncertainty about estimated parameters, it was originally [proposed](https://projecteuclid.org/euclid.aos/1176344552) by [Bradley Efron](https://en.wikipedia.org/wiki/Bradley_Efron). The idea is to generate many new synthetic datasets from the initial true dataset by randomly sampling from it, then finding estimators for each one of these new datasets, and finally looking at the distribution of all these estimators to quantify our confidence.
#
# Note that each new resampled datasets will be the same size as our original one, with the new data points sampled with replacement i.e. we can repeat the same data point multiple times. Also note that in practice we need a lot of resampled datasets.
#
# To explore this idea, we will work againg wit the "experimental data" generated above (the DataFrame `exp_data`).
#
#
# **Generate resampled data and display the psychometric curves for the original and the resampled data.** Repeat this several times to get a feeling for the "randomness", that is how different the resampled data is from the original data.

# %%
bootstrap_sample = exp_data.sample(n=len(exp_data), replace=True)

# plot psychometric curve
plot_data_psychometric(exp_data)
plot_data_psychometric(bootstrap_sample)
plt.legend(('Original','Resampled'));

# %% [markdown]
# ## Generate bootstrap estimates
#
# In this exercise you will implement a method to run the bootstrap process of generating a set of fitted parameters from a dataset.

# %% [markdown]
# We will do this for model B, that is, we will fit the model B and return an array with the fitted parameters $\sigma_m$ and $\lambda$.

# %%
def bootstrap_estimates(data, n=2000):
  """Generate a set of theta_hat estimates using the bootstrap method.
  Args:
    data (DataFrame)
    n (int): The number of estimates to compute
  Returns:
    ndarray: An array of estimated parameters with size (n,)
  """

  theta_hats = np.zeros((n,2))

  # Loop over number of estimates
  for i in range(n):

    # Resample data
    bootstrap_sample = data.sample(n=len(data), replace=True)
    
    # Compute theta_hat for this sample
    
    theta_hats[i,:]=optimize.minimize(lambda pp: -LogLikelihood_modelB(bootstrap_sample, pp[0], pp[1]), x0=[0.75, 0.1], bounds=[(0.1, 10), (0.01, 1)]).x 

  return theta_hats

# Get bootstrap estimates (generate only 3 bootstrap samples for a quick check if everything works)
theta_hats = bootstrap_estimates(exp_data, n=500)

# %% [markdown]
# ## Plot bootstrap samples and confidence intervals
#
# Let us now quantify how uncertain our estimated parameters ($\sigma_m$ and $\lambda$) are. We do so by computing confidence intervals from our bootstrapped estimates. The most direct approach is to compute percentiles from the empirical distribution of bootstrapped estimates. Note that this is widely applicable as we are not assuming that this empirical distribution is Gaussian.

# %%
means = np.mean(theta_hats,axis=0)
stds = np.std(theta_hats,axis=0)
medians = np.percentile(theta_hats, 50, axis=0)
CIs = np.percentile(theta_hats, 95, axis=0)  # compute 95% confidence intervals

fig, ax = plt.subplots(ncols=2, figsize=(12, 5))

for i in range(2):
    ax[i].hist(theta_hats[:,i], bins=20, facecolor='C1', alpha=0.75);
    ax[i].axvline(medians[i], color='r', label='Median')

    ax[i].axvline(CIs[i], color='b', label='95% CI')
    
   
    
    ax[i].legend()
    ax[i].set(
        title='Bootstrapped Confidence Interval for parameter '+str(i),
        xlabel=r'$\hat{{w_' + str(i) +'}}$',
        ylabel='count');

# %% [markdown]
# ## Illustrate bootstrap estimates (show fitted psychometric functions)
#
# Now that we have our bootstrap estimates, we can visualize all the potential models (models computed with different resampling) together to see how distributed they are.

# %%
fig, ax = plt.subplots()

# plot all model fits obtained from bootstrap samples
for i, theta_hat in enumerate(theta_hats):
    plot_model(lambda s,c: p_modelB(s,c,sigma_d=theta_hat[0], Lambda=theta_hat[1]))

# make the lines transparant to get a feeling for the distribution of model fits
for line in plt.gca().lines:
    line.set_alpha(0.005)

plot_data_psychometric(exp_data)

# %% [markdown]
# ## Summary of bootstrapping
#
# - Bootstrapping is a resampling procedure that allows to build confidence intervals around inferred parameter values
# - it is a widely applicable and very practical method that relies on computational power and pseudo-random number generators (as opposed to more classical approaches than depend on analytical derivations)
# - is non-parametric: the confidence intervals provided by statistical libraries are not always accurate because they assume an underlying gaussian distribution for parameters, which is not always the case.

# %% [markdown]
# ---
# # Optional part: Parameter trade-off between $\lambda$ and $\sigma$

# %% [markdown]
# Above we have run a parameter recover analysis for model B that has a fixed $\sigma_c$ across the two experimental condtions, and only $\lambda$ is different between the conditions. Here, we will consider a more interesting example, let's call it model C. In model C, we also allow $\sigma_m$ to change between conditions, that is in the manipulated condition is now described by a $\lambda$ and a $\sigma_m$.

# %% [markdown]
# To make the above code direclty reusable, we simplify a bit and only consider "manipulation" trials.

# %% [markdown]
# **What do you observe, when using model B to fit the data obtained by model C?**

# %%
# loop over at least 100 repetitions
n_rep = 500

# specify parameters of the experiment
n = 2500  # number of trials
stim_values = [-3, -2, -1, -.5, 0,.5, 1, 2, 3]  # all possible values of stimulus evidence (i.e. signed stim strength)

# specify plaubsible range of model parameters
sigma = 0.5 + 2*np.random.rand(n_rep)
Lambda = 0.3 * np.random.rand(n_rep)


pars = np.zeros((n_rep,2))
for i in range(n_rep):
        
    # first generate experimental conditions for each trial
    c = np.random.choice(a=['manipulation', 'manipulation'], size=n) # condition
    s = np.random.choice(a=stim_values, size=n) #stimulus evidence

    # simulate model B
    r = simulate_modelC(s, c, sigma_d=sigma[i], sigma_m=sigma[i], Lambda=Lambda[i])
    df = pd.DataFrame({'stimulus': s, 'condition': c, 'response': r})

    # fit model B
    result = optimize.minimize(lambda pp: -LogLikelihood_modelB(df, pp[0], pp[1]), x0=[0.75, 0.1], bounds=[(0.1, 10), (0.01, 1)])


    # store fitted parameters
    pars[i,0] = result.x[0]
    pars[i,1] = result.x[1]

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 4))

#first subplot
axs[0].scatter(sigma, pars[:,0], marker='X', color='purple', alpha = 0.5)
axs[0].plot([0.2,2.7], [0.2,2.7], 'k--')
axs[0].set_title('noise standard deviation')
axs[0].set_xlabel('true sigma')
axs[0].set_ylabel('fitted sigma')

#second subplot
axs[1].scatter(Lambda, pars[:,1], marker='X', color='purple', alpha = 0.5)
axs[1].plot([0, 0.5], [0, 0.5], 'k--')
axs[1].set_title('lapse rate')
axs[1].set_xlabel('true lambda')
axs[1].set_ylabel('fitted lambda')

#third subplot
axs[2].scatter(pars[:,0], pars[:,1], marker='X', color='purple', alpha = 0.5)
axs[2].set_title('correlation between fitted parameters')
axs[2].set_xlabel('fitted sigma')
axs[2].set_ylabel('fitted lambda')

plt.tight_layout()  

plt.show()
